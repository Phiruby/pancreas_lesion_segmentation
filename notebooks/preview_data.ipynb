# %% [markdown]
# ## Previewing the Data
#
# This note book will focus on loading data, understanding their associated metadata (eg: shape) and visualizing them

# %%
import nibabel as nib
import numpy as np

# Load the image
image = nib.load("C:/Users/viloh/Documents/M31 Task/data/train/subtype0/quiz_0_041_0000.nii.gz")
image_segment = nib.load("C:/Users/viloh/Documents/M31 Task/data/train/subtype0/quiz_0_041.nii.gz")
# label = nib.load("label.nii.gz")

# Ensure consistent orientation and voxel size
image_data = image.get_fdata()
image_segment = image_segment.get_fdata()
# label_data = label.get_fdata()

# %%
unique_values = np.unique(image_segment)
print(unique_values)
non_zero_indices = np.argwhere(image_segment != 0)
print(non_zero_indices)
print(image_segment[150][91][25])
# Out:
# [0. 1. 2.]
# [[ 10  41  75]
#  [ 10  41  76]
#  [ 10  41  77]
#  ...
#  [150  91  25]
#  [150  91  26]
#  [150  92  24]]
# 1.0

# %%
import matplotlib.pyplot as plt
plt.imshow(image_data[:,:,25], cmap="gray")
plt.imshow(image_segment[:,:,25], cmap="jet", alpha=0.5)
plt.show()
